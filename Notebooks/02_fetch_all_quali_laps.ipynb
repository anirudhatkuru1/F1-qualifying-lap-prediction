# %%
import requests
import pandas as pd

# Load session keys with year from the CSV saved above
df_sessions = pd.read_csv("../data/all_qualifying_sessions_2015_2024.csv")
session_keys = df_sessions["session_key"].tolist()

all_laps = []

for key in session_keys:
    print(f"Fetching laps for session {key}...")
    url = "https://api.openf1.org/v1/laps"
    params = {"session_key": key}
    
    response = requests.get(url, params=params)
    laps = response.json()
    
    if laps:
        for lap in laps:
            lap["session_key"] = key
            # add year info too by matching session_key with session dataframe
            lap["year"] = int(df_sessions[df_sessions["session_key"] == key]["year"].values[0])
        all_laps.extend(laps)

df_all_laps = pd.DataFrame(all_laps)
print(f"Total laps fetched: {len(df_all_laps)}")

# Save combined CSV
df_all_laps.to_csv("../data/all_quali_2015_2024.csv", index=False)
print("✅ Saved all qualifying laps 2015-2024 to ../data/all_quali_2015_2024.csv")
# Out:
# Fetching laps for session 7768...
# Fetching laps for session 7775...
# Fetching laps for session 7783...
# Fetching laps for session 9064...
# Fetching laps for session 9074...
# Fetching laps for session 9090...
# Fetching laps for session 9098...
# Fetching laps for session 9106...
# Fetching laps for session 9112...
# Fetching laps for session 9122...
# Fetching laps for session 9129...
# Fetching laps for session 9135...
# Fetching laps for session 9145...
# Fetching laps for session 9153...
# Fetching laps for session 9161...
# Fetching laps for session 9169...
# Fetching laps for session 9215...
# Fetching laps for session 9207...
# Fetching laps for session 9177...
# Fetching laps for session 9304...
# Fetching laps for session 9314...
# Fetching laps for session 9193...
# Fetching laps for session 9468...
# Fetching laps for session 9476...
# Fetching laps for session 9484...
# Fetching laps for session 9492...
# Fetching laps for session 9664...
# Fetching laps for session 9498...
# Fetching laps for session 9511...
# Fetching laps for session 9519...
# Fetching laps for session 9527...
# Fetching laps for session 9535...
# Fetching laps for session 9541...
# Fetching laps for session 9554...
# Fetching laps for session 9562...
# Fetching laps for session 9570...
# Fetching laps for session 9578...
# Fetching laps for session 9586...
# Fetching laps for session 9594...
# Fetching laps for session 9602...
# Fetching laps for session 9608...
# Fetching laps for session 9621...
# Fetching laps for session 9627...
# Fetching laps for session 9640...
# Fetching laps for session 9646...
# Fetching laps for session 9658...
# Total laps fetched: 15021
# ✅ Saved all qualifying laps 2015-2024 to ../data/all_quali_2015_2024.csv
